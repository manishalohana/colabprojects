# %%
import cv2
import numpy as np

# %%
img = cv2.imread('/content/randm.jpg')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.medianBlur(gray, 5)
edges = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 9, 9)

# %%
color = cv2.bilateralFilter(img, 9, 300, 300)

# %%
cartoon = cv2.bitwise_and(color, color, mask=edges)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
cv2_imshow(cartoon)
cv2_imshow(color)
cv2_imshow(edges)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1000x667 at 0x7F8049A53400>
# <PIL.Image.Image image mode=RGB size=1000x667 at 0x7F8049A530A0>
# <PIL.Image.Image image mode=RGB size=1000x667 at 0x7F8049A536D0>
# <PIL.Image.Image image mode=L size=1000x667 at 0x7F805A8D1190>
